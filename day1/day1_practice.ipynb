# %% [markdown]
# # 実践演習 Day 1：streamlitとFastAPIのデモ
# このノートブックでは以下の内容を学習します。
#
# - 必要なライブラリのインストールと環境設定
# - Hugging Faceからモデルを用いたStreamlitのデモアプリ
# - FastAPIとngrokを使用したAPIの公開方法
#
# 演習を始める前に、HuggingFaceとngrokのアカウントを作成し、
# それぞれのAPIトークンを取得する必要があります。
#
#
# 演習の時間では、以下の3つのディレクトリを順に説明します。
#
# 1. 01_streamlit_UI
# 2. 02_streamlit_app
# 3. 03_FastAPI
#
# 2つ目や3つ目からでも始められる様にノートブックを作成しています。
#
# 復習の際にもこのノートブックを役立てていただければと思います。
#
# ### 注意事項
# 「02_streamlit_app」と「03_FastAPI」では、GPUを使用します。
#
# これらを実行する際は、Google Colab画面上のメニューから「編集」→ 「ノートブックの設定」
#
# 「ハードウェアアクセラレーター」の項目の中から、「T4 GPU」を選択してください。
#
# このノートブックのデフォルトは「CPU」になっています。
#
# ---

# %% [markdown]
# # 環境変数の設定（1~3共有）

# %% [markdown]
# GitHubから演習用のコードをCloneします。

# %%
# !git clone https://github.com/matsuolab/lecture-ai-engineering.git
# Out:
# Cloning into 'lecture-ai-engineering'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 41 (delta 7), reused 4 (delta 4), pack-reused 8 (from 1)
# Receiving objects: 100% (41/41), 34.03 KiB | 11.34 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# 必要なAPIトークンを.envに設定します。
#
# 「lecture-ai-engineering/day1」の配下に、「.env_template」ファイルが存在しています。
#
# 隠しファイルのため表示されていない場合は、画面左側のある、目のアイコンの「隠しファイルの表示」ボタンを押してください。
#
# 「.env_template」のファイル名を「.env」に変更します。「.env」ファイルを開くと、以下のような中身になっています。
#
#
# ```
# HUGGINGFACE_TOKEN="hf-********"
# NGROK_TOKEN="********"
# ```
# ダブルクオーテーションで囲まれた文字列をHuggingfaceのアクセストークンと、ngrokの認証トークンで書き変えてください。
#
# それぞれのアカウントが作成済みであれば、以下のURLからそれぞれのトークンを取得できます。
#
# - Huggingfaceのアクセストークン
# https://huggingface.co/docs/hub/security-tokens
#
# - ngrokの認証トークン
# https://dashboard.ngrok.com/get-started/your-authtoken
#
# 書き換えたら、「.env」ファイルをローカルのPCにダウンロードしてください。
#
# 「01_streamlit_UI」から「02_streamlit_app」へ進む際に、CPUからGPUの利用に切り替えるため、セッションが一度切れてしまいます。
#
# その際に、トークンを設定した「.env」ファイルは再作成することになるので、その手間を減らすために「.env」ファイルをダウンロードしておくと良いです。

# %% [markdown]
# 「.env」ファイルを読み込み、環境変数として設定します。次のセルを実行し、最終的に「True」が表示されていればうまく読み込めています。

# %%
# !pip install python-dotenv
from dotenv import load_dotenv, find_dotenv

# %cd /content/lecture-ai-engineering/day1
load_dotenv(find_dotenv())
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.0
# /content/lecture-ai-engineering/day1
# True

# %% [markdown]
# # 01_streamlit_UI
#
# ディレクトリ「01_streamlit_UI」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/01_streamlit_UI
# Out:
# /content/lecture-ai-engineering/day1/01_streamlit_UI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# アプリを起動します。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py
# Out:
# 公開URL: https://ced5-35-245-33-199.ngrok-free.app
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.245.33.199:8501
#
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# [*********************100%***********************]  1 of 1 completed
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# [*********************100%***********************]  1 of 1 completed
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# [*********************100%***********************]  1 of 1 completed
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   121 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:640 in code_to_exec
#
#   /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52 in <module>
#
#      49 │   │   # 最新の株価データ表示
#      50 │   │   latest_data = data.iloc[-1]
#      51 │   │   col1, col2, col3, col4 = st.columns(4)
#   ❱  52 │   │   col1.metric("始値", f"{latest_data['Open']:.2f}")
#      53 │   │   col2.metric("高値", f"{latest_data['High']:.2f}")
#      54 │   │   col3.metric("安値", f"{latest_data['Low']:.2f}")
#      55 │   │   col4.metric("終値", f"{latest_data['Close']:.2f}")
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: unsupported format string passed to Series.__format__
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   col1.metric("始値", f"{float(latest_data['Open']):.2f}")
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   col2.metric("高値", f"{float(latest_data['High']):.2f}")
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   col3.metric("安値", f"{float(latest_data['Low']):.2f}")
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   col4.metric("終値", f"{float(latest_data['Close']):.2f}")
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:52: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:53: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:54: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:55: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:102: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:103: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:104: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:105: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:106: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:107: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# 2025-04-24 17:11:34.573 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 103
#     fig = go.Figure()
#     ^^^
# SyntaxError: expected 'except' or 'finally' block
# 2025-04-24 17:11:34.578 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:12:04.746 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 103
#     fig = go.Figure()
#     ^^^
# SyntaxError: expected 'except' or 'finally' block
# 2025-04-24 17:12:04.749 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:12:06.475 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 103
#     fig = go.Figure()
#     ^^^
# SyntaxError: expected 'except' or 'finally' block
# 2025-04-24 17:12:06.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:12:57.424 Received event for non-watched file: /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py
# 2025-04-24 17:12:57.425 Received event for non-watched file: /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py
# 2025-04-24 17:13:01.698 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 111
#     fig.add_trace(
#     ^^^
# SyntaxError: expected 'except' or 'finally' block
# 2025-04-24 17:13:01.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:14:05.896 Received event for non-watched file: /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:91: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:162: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:163: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:164: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:165: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:166: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:167: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:91: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:162: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:163: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:164: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:165: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:166: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:167: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:91: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:162: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:163: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:164: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:165: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:166: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:167: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:91: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:162: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:163: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:164: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:165: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:166: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:167: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:90: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:91: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:162: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:163: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:164: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:165: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:166: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:167: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:88: FutureWarning:
#
# Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:89: FutureWarning:
#
# ...
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:56: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:56: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2025-04-24 17:33:43.447 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 12
#     stock_symbol = st.sidebar.text_input("株式シンボルを入力してください", /n "（例：7203.T, AAPL）:', '7203.T")
#                                                             ^
# SyntaxError: invalid syntax
# 2025-04-24 17:33:43.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:34:06.414 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 12
#     stock_symbol = st.sidebar.text_input("株式シンボルを入力してください"+ /n + "（例：7203.T, AAPL）:', '7203.T")
#                                                             ^
# SyntaxError: invalid syntax
# 2025-04-24 17:34:06.419 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 12
#     stock_symbol = st.sidebar.text_input("株式シンボルを入力してください"+ /n + "（例：7203.T, AAPL）:', '7203.T")
#                                                             ^
# SyntaxError: invalid syntax
# 2025-04-24 17:34:06.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:34:12.167 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 12
#     stock_symbol = st.sidebar.text_input("株式シンボルを入力してください"+ /n + "（例：7203.T, AAPL）:', '7203.T")
#                                                             ^
# SyntaxError: invalid syntax
# 2025-04-24 17:34:12.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:34:24.084 Received event for non-watched file: /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['998407.O']: YFTzMissingError('possibly delisted; no timezone found')
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['GSPC']: YFTzMissingError('possibly delisted; no timezone found')
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# 2025-04-24 17:44:16.556 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 56
#     st.subheader("株価推移")
#                         ^
# IndentationError: unindent does not match any outer indentation level
# 2025-04-24 17:44:16.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:44:43.464 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 54
#     st.subheader(f"{company_name} ({stock_symbol})"
#                 ^
# SyntaxError: '(' was never closed
# 2025-04-24 17:44:43.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-24 17:44:49.293 Script compilation error
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 549, in _run_script
#     code = self._script_cache.get_bytecode(script_path)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/script_cache.py", line 72, in get_bytecode
#     filebody = magic.add_magic(filebody, script_path)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/streamlit/runtime/scriptrunner/magic.py", line 46, in add_magic
#     tree = ast.parse(code, script_path, "exec")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/lecture-ai-engineering/day1/01_streamlit_UI/app.py", line 58
#     st.subheader("株価推移")
#                         ^
# IndentationError: unindent does not match any outer indentation level
# 2025-04-24 17:44:49.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# [*********************100%***********************]  1 of 1 completed
# /content/lecture-ai-engineering/day1/01_streamlit_UI/app.py:38: FutureWarning:
#
# DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.

# %% [markdown]
# 公開URLの後に記載されているURLにブラウザでアクセスすると、streamlitのUIが表示されます。
#
# app.pyのコメントアウトされている箇所を編集することで、UIがどの様に変化するか確認してみましょう。
#
# streamlitの公式ページには、ギャラリーページがあります。
#
# streamlitを使うとpythonという一つの言語であっても、様々なUIを実現できることがわかると思います。
#
# https://streamlit.io/gallery

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 02_streamlit_app

# %% [markdown]
# ディレクトリ「02_streamlit_app」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/02_streamlit_app

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN

# %% [markdown]
# stramlitでHuggingfaceのトークン情報を扱うために、streamlit用の設定ファイル（.streamlit）を作成し、トークンの情報を格納します。

# %%
# .streamlit/secrets.toml ファイルを作成
import os
import toml

# 設定ファイルのディレクトリ確保
os.makedirs('.streamlit', exist_ok=True)

# 環境変数から取得したトークンを設定ファイルに書き込む
secrets = {
    "huggingface": {
        "token": os.environ.get("HUGGINGFACE_TOKEN", "")
    }
}

# 設定ファイルを書き込む
with open('.streamlit/secrets.toml', 'w') as f:
    toml.dump(secrets, f)

# %% [markdown]
# アプリを起動します。
#
# 02_streamlit_appでは、Huggingfaceからモデルをダウンロードするため、初回起動には2分程度時間がかかります。
#
# この待ち時間を利用して、app.pyのコードを確認してみましょう。

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501).public_url
print(f"公開URL: {public_url}")
# !streamlit run app.py

# %% [markdown]
# アプリケーションの機能としては、チャット機能や履歴閲覧があります。
#
# これらの機能を実現するためには、StreamlitによるUI部分だけではなく、SQLiteを使用したチャット履歴の保存やLLMのモデルを呼び出した推論などの処理を組み合わせることで実現しています。
#
# - **`app.py`**: アプリケーションのエントリーポイント。チャット機能、履歴閲覧、サンプルデータ管理のUIを提供します。
# - **`ui.py`**: チャットページや履歴閲覧ページなど、アプリケーションのUIロジックを管理します。
# - **`llm.py`**: LLMモデルのロードとテキスト生成を行うモジュール。
# - **`database.py`**: SQLiteデータベースを使用してチャット履歴やフィードバックを保存・管理します。
# - **`metrics.py`**: BLEUスコアやコサイン類似度など、回答の評価指標を計算するモジュール。
# - **`data.py`**: サンプルデータの作成やデータベースの初期化を行うモジュール。
# - **`config.py`**: アプリケーションの設定（モデル名やデータベースファイル名）を管理します。
# - **`requirements.txt`**: このアプリケーションを実行するために必要なPythonパッケージ。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()

# %% [markdown]
# # 03_FastAPI
#
# ディレクトリ「03_FastAPI」に移動します。

# %%
# %cd /content/lecture-ai-engineering/day1/03_FastAPI

# %% [markdown]
# 必要なライブラリをインストールします。

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ngrokとhuggigfaceのトークンを使用して、認証を行います。

# %%
# !ngrok authtoken $$NGROK_TOKEN
# !huggingface-cli login --token $$HUGGINGFACE_TOKEN

# %% [markdown]
# アプリを起動します。
#
# 「02_streamlit_app」から続けて「03_FastAPI」を実行している場合は、モデルのダウンロードが済んでいるため、すぐにサービスが立ち上がります。
#
# 「03_FastAPI」のみを実行している場合は、初回の起動時にモデルのダウンロードが始まるので、モデルのダウンロードが終わるまで数分間待ちましょう。

# %%
# !python app.py

# %% [markdown]
# FastAPIが起動すると、APIとクライアントが通信するためのURL（エンドポイント）が作られます。
#
# URLが作られるのと合わせて、Swagger UIというWebインターフェースが作られます。
#
# Swagger UIにアクセスすることで、APIの仕様を確認できたり、APIをテストすることができます。
#
# Swagger UIを利用することで、APIを通してLLMを動かしてみましょう。

# %% [markdown]
# 後片付けとして、使う必要のないngrokのトンネルを削除します。

# %%
from pyngrok import ngrok
ngrok.kill()
